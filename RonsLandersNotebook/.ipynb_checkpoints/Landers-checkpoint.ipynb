# %%
import requests
from config import email, key
import pandas as pd
import matplotlib.pyplot as plt

# %%
# base_url finds air quality readings by Box

base_url = "https://aqs.epa.gov/data/api/sampleData/byBox?"

#parameters for byBox for CRITERIA Pollutants 
#42401="Sulfur Dioxide" 
#42602="Nitrogen Dioxide"
#42201="Ozone"
#42101 = "Carbon Monoxide"

#Landers, CA eartquake 1992-06-28, (34.200, -116.437)
#search for readings performed 1 week before to 1 week after the event
#search for readings in .5 degree radius of the event epicenter

param_url = "param=42401,42602,44201,42101"
date_range_url = "bdate=19920621&edate=19920705"
geometry_url = "minlat=33.200&maxlat=35.200&minlon=-117.437&maxlon=-115.437"

url = (base_url + param_url + "&email=" + email + "&key=" + key + "&" + date_range_url + "&" + geometry_url)

# %%
#j Perform the search, jsonify the results, and store the data as "response"

search = requests.get(url)
response = search.json()
response
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2019-10-14T18:50:29-04:00',
#    'url': 'https://aqs.epa.gov/data/api/sampleData/byBox?param=42401,42602,44201,42101&email=ronneimark@hotmail.com&key=tawnybird31&bdate=19920621&edate=19920705&minlat=33.200&maxlat=35.200&minlon=-117.437&maxlon=-115.437',
#    'rows': 12143}],
#  'Data': [{'state_code': '06',
#    'county_code': '071',
#    'site_number': '9010',
#    'parameter_code': '42401',
#    'poc': 1,
#    'latitude': 34.193925,
#    'longitude': -116.914063,
#    'datum': 'WGS84',
#    'parameter': 'Sulfur dioxide',
#    'date_local': '1992-06-24',
#    'time_local': '00:00',
#    'date_gmt': '1992-06-24',
#    'time_gmt': '08:00',
#    'sample_measurement': 0.2,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '24 HOUR',
#    'sample_frequency': 'EVERY 3RD DAY',
#    'detection_limit': 0.0895,
#    'uncertainty': 0.0596,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '811',
#    'method': 'IMPROVE Module D with Cyclone Inlet-Quartz Filter, 2.2 sq. cm. - Ion Chromatography',
#    'state': 'California',
#    'county': 'San Bernardino',
#    'date_of_last_change': None,
#    'cbsa_code': '40140'},
#   {'state_code': '06',
#    'county_code': '071',
#    'site_number': '9010',
#    'parameter_code': '42401',
#    'poc': 1,
#    'latitude': 34.193925,
#    'longitude': -116.914063,
#    'datum': 'WGS84',
#    'parameter': 'Sulfur dioxide',
#    'date_local': '1992-07-01',
#    'time_local': '00:00',
#    'date_gmt': '1992-07-01',
#    'time_gmt': '08:00',
#    'sample_measurement': 0.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '24 HOUR',
#    'sample_frequency': 'EVERY 3RD DAY',
#    'detection_limit': 0.0844,
#    'uncertainty': 0.0428,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '811',
#    'method': 'IMPROVE Module D with Cyclone Inlet-Quartz Filter, 2.2 sq. cm. - Ion Chromatography',
#    'state': 'California',
#    'county': 'San Bernardino',
#    'date_of_last_change': None,
#    'cbsa_code': '40140'},
#   {'state_code': '06',
#    'county_code': '071',
#    'site_number': '9010',
#    'parameter_code': '42401',
#    'poc': 1,
#    'latitude': 34.193925,
#    'longitude': -116.914063,
#    'datum': 'WGS84',
#    'parameter': 'Sulfur dioxide',
#    'date_local': '1992-07-04',
#    'time_local': '00:00',
#    'date_gmt': '1992-07-04',
#    'time_gmt': '08:00',
#    'sample_measurement': 0.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '24 HOUR',
#    'sample_frequency': 'EVERY 3RD DAY',
#    'detection_limit': 0.0935,
#    'uncertainty': 0.0486,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '811',
#    'method': 'IMPROVE Module D with Cyclone Inlet-Quartz Filter, 2.2 sq. cm. - Ion Chromatography',
#    'state': 'California',
#    'county': 'San Bernardino',
#    'date_of_last_change': None,
#    'cbsa_code': '40140'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '00:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '08:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '01:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '09:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '02:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '10:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '03:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '11:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '04:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '12:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '05:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '13:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '06:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '14:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '07:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '15:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '08:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '16:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '09:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '17:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '10:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '18:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '11:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '19:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '12:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '20:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '13:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '21:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '14:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '22:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '15:00',
#    'date_gmt': '1992-06-21',
#    'time_gmt': '23:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '16:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '00:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '17:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '01:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '18:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '02:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '19:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '03:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '20:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '04:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '21:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '05:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '22:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '06:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-21',
#    'time_local': '23:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '07:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '00:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '08:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '01:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '09:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '02:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '10:00',
#    'sample_measurement': 10.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '03:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '11:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '04:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '12:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '05:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '13:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '06:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '14:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '07:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '15:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '08:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '16:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '09:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '17:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '10:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '18:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '11:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '19:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '12:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '20:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '13:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '21:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '14:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '22:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '15:00',
#    'date_gmt': '1992-06-22',
#    'time_gmt': '23:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '16:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '00:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '17:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '01:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '18:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '02:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '19:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '03:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '20:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '04:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '21:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '05:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '22:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '06:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-22',
#    'time_local': '23:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '07:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '00:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '08:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '01:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '09:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '02:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '10:00',
#    'sample_measurement': 20.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '03:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '11:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '04:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '12:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '05:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '13:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '06:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '14:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '07:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '15:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '08:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '16:00',
#    'sample_measurement': 40.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '09:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '17:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 5.0,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '42602',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Nitrogen dioxide (NO2)',
#    'date_local': '1992-06-23',
#    'time_local': '10:00',
#    'date_gmt': '1992-06-23',
#    'time_gmt': '18:00',
#    'sample_measurement': 30.0,
#    'units_of_measure': 'Parts per billion',
#    'sample_duration': '1 HOUR',
# ...
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '06:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '14:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '07:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '15:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '11:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '19:00',
#    'sample_measurement': 0.03,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '12:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '20:00',
#    'sample_measurement': 0.03,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '13:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '21:00',
#    'sample_measurement': 0.03,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '14:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '22:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '15:00',
#    'date_gmt': '1992-07-02',
#    'time_gmt': '23:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '16:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '00:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '17:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '01:00',
#    'sample_measurement': 0.03,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '18:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '02:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '19:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '03:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '20:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '04:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '21:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '05:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '22:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.02,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-02',
#    'time_local': '23:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '07:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '00:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '08:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '01:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '09:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '02:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '10:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '03:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '11:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '04:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '12:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   {'state_code': '06',
#    'county_code': '073',
#    'site_number': '0005',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 33.202686,
#    'longitude': -117.366797,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'date_local': '1992-07-03',
#    'time_local': '05:00',
#    'date_gmt': '1992-07-03',
#    'time_gmt': '13:00',
#    'sample_measurement': 0.01,
#    'units_of_measure': 'Parts per million',
#    'sample_duration': '1 HOUR',
#    'sample_frequency': 'HOURLY',
#    'detection_limit': 0.005,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'FRM',
#    'method_code': '014',
#    'method': 'INSTRUMENTAL - CHEMILUMINESCENCE',
#    'state': 'California',
#    'county': 'San Diego',
#    'date_of_last_change': None,
#    'cbsa_code': '41740'},
#   ...]}

# %%
# iterate through the json data and establish a dataframe of the relevant fields

record_list = []
i=0

for record in response['Data']:
    county = response['Data'][i]['county']
    station = response['Data'][i]['site_number']
    parameter = response['Data'][i]['parameter']
    date = response['Data'][i]['date_local']
    time = response['Data'][i]['time_local']
    measurement = response['Data'][i]['sample_measurement']
    measurement_unit = response['Data'][i]['units_of_measure']
    record_dict = {"Parameter":parameter,"Date":date,"Time":time,"County":county,"Station":station,"Measurement":measurement,"Unit":measurement_unit}
    record_list.append(record_dict)

    i += 1
    
record_df = pd.DataFrame(record_list)

record_df.head()

# also create dataframe grouped by Parameter and Date

recordgroupby_df = record_df.groupby(['Parameter','Date'],as_index=False).mean()
record_df
# Out:
#                     Parameter        Date   Time          County Station  \
# 0              Sulfur dioxide  1992-06-24  00:00  San Bernardino    9010
# 1              Sulfur dioxide  1992-07-01  00:00  San Bernardino    9010
# 2              Sulfur dioxide  1992-07-04  00:00  San Bernardino    9010
# 3      Nitrogen dioxide (NO2)  1992-06-21  00:00       San Diego    0005
# 4      Nitrogen dioxide (NO2)  1992-06-21  01:00       San Diego    0005
# ...                       ...         ...    ...             ...     ...
# 12138                   Ozone  1992-07-05  19:00       Riverside    0002
# 12139                   Ozone  1992-07-05  20:00       Riverside    0002
# 12140                   Ozone  1992-07-05  21:00       Riverside    0002
# 12141                   Ozone  1992-07-05  22:00       Riverside    0002
# 12142                   Ozone  1992-07-05  23:00       Riverside    0002
#
#        Measurement               Unit
# 0             0.20  Parts per billion
# 1             0.00  Parts per billion
# 2             0.00  Parts per billion
# 3            10.00  Parts per billion
# 4            10.00  Parts per billion
# ...            ...                ...
# 12138         0.11  Parts per million
# 12139         0.09  Parts per million
# 12140         0.08  Parts per million
# 12141         0.07  Parts per million
# 12142         0.05  Parts per million
#
# [12143 rows x 7 columns]

# %%
# save dataframes to a csv file. 

record_df.to_csv("Records.csv")
recordgroupby_df.to_csv("RecordsByStation.csv")

# %%
#Extract NO2 data from the groupby

Nitrogen_Dioxide = recordgroupby_df['Parameter']=="Nitrogen dioxide (NO2)"
record_NO2 = recordgroupby_df[Nitrogen_Dioxide]
record_NO2.head()
# Out:
#                  Parameter        Date  Measurement
# 15  Nitrogen dioxide (NO2)  1992-06-21    22.345679
# 16  Nitrogen dioxide (NO2)  1992-06-22    28.187500
# 17  Nitrogen dioxide (NO2)  1992-06-23    28.616352
# 18  Nitrogen dioxide (NO2)  1992-06-24    24.629630
# 19  Nitrogen dioxide (NO2)  1992-06-25    23.899371

# %%
# Plot the NO2 data with line chart

plt.plot(record_NO2['Date'],record_NO2['Measurement'])
plt.title('{0}'.format("NO2 Before and After Seismic Event"), fontsize =38)
plt.xlabel("Date (6/28 Event)", fontsize = 18)
plt.ylabel("NO2 (parts per billion)", fontsize =18)
plt.rcParams["figure.figsize"] = [16,8]
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12
plt.xticks(rotation=45)
plt.show()

# %%
# Extract SO2 data from the groupby dataframe

Sulfur_Dioxide = recordgroupby_df['Parameter']=="Sulfur dioxide"
record_SO2 = recordgroupby_df[Sulfur_Dioxide]
record_SO2.head()
# Out:
#          Parameter        Date  Measurement
# 45  Sulfur dioxide  1992-06-21     0.000000
# 46  Sulfur dioxide  1992-06-22     0.769231
# 47  Sulfur dioxide  1992-06-23     0.967742
# 48  Sulfur dioxide  1992-06-24     0.845263
# 49  Sulfur dioxide  1992-06-25     0.000000

# %%
# Chart the SO2 Data

plt.plot(record_SO2['Date'],record_SO2['Measurement'])
plt.title('{0}'.format("SO2 Before and After Seismic Event"), fontsize =38)
plt.xlabel("Date (6/28 Event)", fontsize = 18)
plt.ylabel("SO2 (parts per billion)", fontsize =18)
plt.rcParams["figure.figsize"] = [16,8]
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12
plt.xticks(rotation=45)
plt.show()

# %%
# Extract Ozone from the groupby dataframe

Ozone = recordgroupby_df['Parameter']=="Ozone"
record_Ozone = recordgroupby_df[Ozone]
record_Ozone.head()
# Out:
#    Parameter        Date  Measurement
# 30     Ozone  1992-06-21     0.057658
# 31     Ozone  1992-06-22     0.049809
# 32     Ozone  1992-06-23     0.045228
# 33     Ozone  1992-06-24     0.035496
# 34     Ozone  1992-06-25     0.053129

# %%
#Chart the Ozone Data

plt.plot(record_Ozone['Date'],record_Ozone['Measurement'])
plt.title('{0}'.format("Ozone Before and After Seismic Event"), fontsize =38)
plt.xlabel("Date (6/28 Event)", fontsize = 18)
plt.ylabel("Ozone (parts per million)", fontsize =18)
plt.rcParams["figure.figsize"] = [16,8]
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12
plt.xticks(rotation=45)
plt.show()

# %%
# Extract CO from the groupby dataframe

Carbon_Monoxide = recordgroupby_df['Parameter']=="Carbon monoxide"
record_CO = recordgroupby_df[Carbon_Monoxide]

record_CO.head()
# Out:
#          Parameter        Date  Measurement
# 0  Carbon monoxide  1992-06-21     0.809816
# 1  Carbon monoxide  1992-06-22     1.149068
# 2  Carbon monoxide  1992-06-23     1.136646
# 3  Carbon monoxide  1992-06-24     0.950617
# 4  Carbon monoxide  1992-06-25     0.975309

# %%
#Chart the Carbon Monoxide Data

plt.plot(record_CO['Date'],record_CO['Measurement'])
plt.title('{0}'.format("CO Before and After Seismic Event"), fontsize =38)
plt.xlabel("Date (6/28 Event)", fontsize = 18)
plt.ylabel("Carbon Monoxide (parts per million)", fontsize =18)
plt.rcParams["figure.figsize"] = [16,8]
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)
plt.setp('Measurement', rotation=45, fontsize = 8)

SO2_graph = plt.plot(record_SO2['Date'],record_SO2['Measurement'])
NO2_graph = plt.plot(record_NO2['Date'],record_NO2['Measurement'], 'tab:orange')
Ozone_graph = plt.plot(record_Ozone['Date'],record_Ozone['Measurement'], 'tab:green')
CO_graph = plt.plot(record_CO['Date'],record_CO['Measurement'], 'tab:red')

plt.legend(['SO2', 'NO2', 'Ozone', 'CO'], loc ='upper right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-174e7bf1c82d> in <module>
#       1 fig = plt.figure(figsize = (10,5))
#       2 ax = fig.add_subplot(111)
# ----> 3 plt.setp(xtickNames, rotation=45, fontsize = 8)
#       4
#       5 SO2_graph = plt.plot(record_SO2['Date'],record_SO2['Measurement'])
#
# NameError: name 'xtickNames' is not defined
